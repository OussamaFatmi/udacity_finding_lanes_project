# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, consult the forums for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    `vertices` should be a numpy array of integer points.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def get_line_slope (line):
    """
    get a hough-line like line's slope 
    if line is y=ax+b the returned value is a 
    """
    #print (line[0][3]-line[0][1],line[0][2]-line[0][0])
    slope=(line[0][3]-line[0][1])/(line[0][2]-line[0][0])
    return slope

def get_line_intercept (line):
    """
    get a hough-line like line's slope 
    if line is y=ax+b the returned value is b 
    """
    slope=get_line_slope(line)
    intercept=line[0][1]-slope*line[0][0]
    return intercept
def line_length(line):
    """
    get a hough-line like line's length in pixels 
    """
    for x1,y1,x2,y2 in line:
        dist=np.sqrt((y2-y1)**2+(x2-x1)**2)
        #print ('---length',dist)
    return dist 
def get_average_line (lines):
    """
    get a representative average line from a series of Hough lines with similar scope 
     
    """
    average_slope=0
    average_intercept=0
    for line in lines: 
        #if line_length(line)>1: 
        average_slope+=get_line_slope(line)
        average_intercept+=get_line_intercept(line)
    line_count=len(lines) 
    #print('line_count',line_count)
    average_slope=average_slope/line_count
    average_intercept=average_intercept/line_count
    
    
    return average_slope,average_intercept

    

def seperate_left_and_right_lanes (img,lines,minimal_slope,maximal_slope):
    #divide lines into left and right lanes' lines
    #create an array for each of left and right lane 
    left_lines=np.empty((0,1,4))
    right_lines=np.empty((0,1,4))
    
    for line in lines:
        for x1,y1,x2,y2 in line:
            #if line_length(line)>50:
                #cv2.line(img, (x1,y1), (x2, y2),[0,0,255],5)
            if x1!=x2 :
                line_slope=get_line_slope(line)
                print ('-> line_slope',line_slope,'Intercept',get_line_intercept(line),'length')
                if abs(line_slope)>minimal_slope and abs(line_slope)<maximal_slope:
                    if line_slope>0:
                        right_lines=np.append(right_lines,[line],axis=0)
                        #print('right_lines')
                        #cv2.line(img, (x1, y1), (x2, y2), [0,255,0], 2)
                    elif line_slope<0 :
                        #print('left_lines')
                        left_lines=np.append(left_lines,[line],axis=0)
                        #cv2.line(img, (x1, y1), (x2, y2), [0,255,0], 2)
                    else :
                        continue
                else:
                    continue
                    
    print ('==============================FINAL COUNT',len(left_lines),len(right_lines))
    return left_lines,right_lines 

def get_x_from_y_coord(y,slope,intercept):
    #x and y are in pixels, values should be integer
    #print ('slope',slope)
    x=int(round((y-intercept)/slope))
    
    return x 

def draw_average_line(img,lines,color,thickness):
    average_slope,average_intercept=get_average_line(lines)
    y_min=int(np.min(np.append(lines[:,:,1],lines[:,:,3])))
    y_max=image.shape[0]
    #y_max=int(np.max(np.append(lines[:,:,1],lines[:,:,3])))
    x_min=int(round(get_x_from_y_coord(y_min,average_slope,average_intercept)))
    x_max=int(round(get_x_from_y_coord(y_max,average_slope,average_intercept)))
    #print ('y_min,y_max',x_min,y_min,x_max, y_max)
    print ('=====>Average  line_slope',average_slope,'Intercept',average_intercept,'length')
    cv2.line(img, (x_min,y_min), (x_max, y_max),color,thickness)
    
def draw_lines(img,lines, color=[255, 0, 0], thickness=15):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
     
    maximal_slope=1
    minimal_slope=0.5
    #lines with slope greater than minimal_slope are not considered 
    L_lines,R_lines=seperate_left_and_right_lanes(img,lines,minimal_slope,maximal_slope)   
    #get average line right 
    draw_average_line(img,R_lines,color,thickness)
    #get average line left 
    draw_average_line(img,L_lines,color,thickness)
    
    
    
def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., γ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + γ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, γ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
#files=os.listdir("test_images/")

#for file in files :
    #if file[0:6]!="output":
        #reading in an image
        #image = mpimg.imread('test_images/'+file)
        #image=cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        #cv2.imwrite('test_images/output'+file,image)
# Out:
# ['outputsolidWhiteCurve.jpg',
#  'outputsolidWhiteRight.jpg',
#  'outputsolidYellowCurve.jpg',
#  'outputsolidYellowCurve2.jpg',
#  'outputsolidYellowLeft.jpg',
#  'outputwhiteCarLaneSwitch.jpg',
#  'solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an import error when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel). Still have problems? Try relaunching Jupyter Notebook from the terminal prompt. Also, consult the forums for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://discussions.udacity.com/t/project-error-of-test-on-videos/274082) for more troubleshooting tips across operating systems.**

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images_output directory.

#########################################################################

import os
#files=os.listdir("test_images/")

#for file in files[0:0]: 
    #if file[0:6]!="output":
#reading in an image
image = mpimg.imread('test_images/'+'solidWhiteRight.jpg')
#turn to gray
copy_img=np.copy(image)
gray=grayscale(copy_img)


#smooth image 
kernel_size=9
blur_gray=gaussian_blur(gray,kernel_size)

#apply Canny
low_threshold=50
high_threshold=150
edges=canny(blur_gray, low_threshold, high_threshold)

#get region of interest
#x_size=image.shape[1]
y_size=image.shape[0]
vertices=np.array([[(120,y_size),(905,y_size),(510,320),(450,320)]], dtype=np.int32)
masked_edges=region_of_interest(edges, vertices)

#Hough lines
#print ('type',masked_edges.shape)
line_image=hough_lines(masked_edges, rho=1, theta=np.pi/180, threshold=1, min_line_len=5, max_line_gap=10)

# Create a "color" binary image to combine with line image
#color_edges = np.dstack((edges, edges, edges))

# Draw the lines on the edge image
lines_edges = cv2.addWeighted(image, 0.5, line_image, 1, 0)

#x=[120,905,510,450,120]
#y=[y_size,y_size,320,320,y_size]
#plt.plot(x,y,'b--',lw=4)
plt.imshow(lines_edges)
cvt_image=cv2.cvtColor(lines_edges, cv2.COLOR_RGB2BGR)
#cv2.imwrite('test_images/output'+file,cvt_image)
# Out:
# -> line_slope 0.5 Intercept 106.0 length
# -> line_slope 0.5625 Intercept 54.5625 length
# -> line_slope 0.5 Intercept 108.0 length
# -> line_slope -0.4166666666666667 Intercept 838.3333333333334 length
# -> line_slope 0.7777777777777778 Intercept -84.0 length
# -> line_slope 0.7368421052631579 Intercept -72.31578947368416 length
# -> line_slope -0.3333333333333333 Intercept 488.66666666666663 length
# -> line_slope -0.7857142857142857 Intercept 678.0714285714286 length
# -> line_slope -1.5 Intercept 1779.5 length
# -> line_slope 1.2307692307692308 Intercept -361.1538461538462 length
# -> line_slope -3.3333333333333335 Intercept 1564.0 length
# -> line_slope 0.18181818181818182 Intercept 365.6363636363636 length
# -> line_slope 0.14285714285714285 Intercept 300.2857142857143 length
# -> line_slope 0.0 Intercept 348.0 length
# -> line_slope -0.14285714285714285 Intercept 415.42857142857144 length
# -> line_slope 0.7 Intercept -47.299999999999955 length
# -> line_slope 0.7272727272727273 Intercept -68.72727272727275 length
# -> line_slope 0.75 Intercept -86.0 length
# -> line_slope 0.5714285714285714 Intercept 53.14285714285717 length
# -> line_slope -0.2222222222222222 Intercept 546.0 length
# -> line_slope -0.2857142857142857 Intercept 522.5714285714286 length
# -> line_slope -5.0 Intercept 4133.0 length
# -> line_slope 0.0 Intercept 397.0 length
# -> line_slope -0.38461538461538464 Intercept 512.1538461538462 length
# -> line_slope 0.6461538461538462 Intercept -12.292307692307702 length
# -> line_slope -3.0 Intercept 2651.0 length
# -> line_slope -3.5 Intercept 2852.0 length
# -> line_slope 0.0 Intercept 345.0 length
# -> line_slope 0.8333333333333334 Intercept -156.33333333333337 length
# -> line_slope 0.8181818181818182 Intercept -158.09090909090912 length
# -> line_slope 0.5882352941176471 Intercept 48.588235294117624 length
# -> line_slope 0.7333333333333333 Intercept -61.73333333333329 length
# -> line_slope 0.8333333333333334 Intercept -95.83333333333337 length
# -> line_slope 2.0 Intercept -833.0 length
# -> line_slope -0.7142857142857143 Intercept 653.2857142857142 length
# -> line_slope -0.14285714285714285 Intercept 405.7142857142857 length
# -> line_slope -0.6551724137931034 Intercept 626.1034482758621 length
# -> line_slope -1.6 Intercept 1640.0 length
# -> line_slope -3.6666666666666665 Intercept 1610.0 length
# -> line_slope -4.5 Intercept 1925.0 length
# -> line_slope -0.3333333333333333 Intercept 536.0 length
# -> line_slope 0.5 Intercept 82.5 length
# -> line_slope 3.5 Intercept -1567.5 length
# -> line_slope -8.0 Intercept 5983.0 length
# -> line_slope 1.2 Intercept -316.6 length
# -> line_slope 1.8 Intercept -632.6 length
# -> line_slope -0.07142857142857142 Intercept 439.7142857142857 length
# -> line_slope 0.5 Intercept 113.5 length
# -> line_slope -1.5 Intercept 1707.5 length
# -> line_slope 0.15384615384615385 Intercept 274.0 length
# -> line_slope 0.0 Intercept 399.0 length
# -> line_slope -5.0 Intercept 2106.0 length
# -> line_slope 0.4 Intercept 150.2 length
# -> line_slope 0.0 Intercept 402.0 length
# -> line_slope -6.0 Intercept 4225.0 length
# -> line_slope -11.0 Intercept 9550.0 length
# -> line_slope -3.0 Intercept 2332.0 length
# -> line_slope -0.5 Intercept 739.0 length
# -> line_slope -0.16666666666666666 Intercept 563.6666666666666 length
# -> line_slope -0.25 Intercept 503.5 length
# -> line_slope -5.0 Intercept 4381.0 length
# -> line_slope -4.5 Intercept 3813.5 length
# -> line_slope -10.0 Intercept 7910.0 length
# -> line_slope -0.2222222222222222 Intercept 555.4444444444445 length
# -> line_slope 0.7272727272727273 Intercept -67.90909090909088 length
# -> line_slope -0.2857142857142857 Intercept 542.8571428571429 length
# -> line_slope -8.0 Intercept 6112.0 length
# -> line_slope -0.6666666666666666 Intercept 632.3333333333333 length
# -> line_slope -0.4 Intercept 558.0 length
# -> line_slope -0.4 Intercept 554.4 length
# -> line_slope 0.5 Intercept 216.0 length
# -> line_slope -0.5 Intercept 558.5 length
# -> line_slope 1.375 Intercept -383.875 length
# -> line_slope -5.0 Intercept 3385.0 length
# -> line_slope -1.2 Intercept 1308.8 length
# -> line_slope -0.125 Intercept 397.625 length
# -> line_slope -4.5 Intercept 1955.0 length
# -> line_slope -5.0 Intercept 3233.0 length
# -> line_slope 1.0 Intercept -207.0 length
# -> line_slope 0.4 Intercept 147.39999999999998 length
# -> line_slope -0.25 Intercept 555.5 length
# -> line_slope -0.25 Intercept 556.75 length
# -> line_slope -8.0 Intercept 6198.0 length
# -> line_slope -0.2222222222222222 Intercept 560.7777777777778 length
# -> line_slope -2.5 Intercept 1980.0 length
# -> line_slope -0.14285714285714285 Intercept 403.2857142857143 length
# -> line_slope -0.16666666666666666 Intercept 551.6666666666666 length
# -> line_slope 0.0 Intercept 394.0 length
# -> line_slope -0.25 Intercept 538.75 length
# -> line_slope 0.0 Intercept 350.0 length
# -> line_slope 0.4 Intercept 198.79999999999995 length
# -> line_slope -0.25 Intercept 547.0 length
# -> line_slope -0.8 Intercept 686.4000000000001 length
# -> line_slope -0.2222222222222222 Intercept 528.5555555555555 length
# -> line_slope 0.0 Intercept 516.0 length
# -> line_slope -0.3333333333333333 Intercept 485.66666666666663 length
# -> line_slope -0.18181818181818182 Intercept 587.0909090909091 length
# -> line_slope -8.0 Intercept 5965.0 length
# -> line_slope 0.5 Intercept 77.5 length
# -> line_slope -1.0 Intercept 765.0 length
# -> line_slope -0.2857142857142857 Intercept 541.5714285714286 length
# -> line_slope 2.25 Intercept -838.5 length
# -> line_slope 0.0 Intercept 392.0 length
# -> line_slope 1.4285714285714286 Intercept -410.7142857142858 length
# -> line_slope 0.09090909090909091 Intercept 313.45454545454544 length
# -> line_slope 0.5833333333333334 Intercept 33.083333333333314 length
# -> line_slope 1.5 Intercept -482.0 length
# -> line_slope -5.0 Intercept 4235.0 length
# -> line_slope 0.0 Intercept 521.0 length
# -> line_slope -1.8 Intercept 1935.8 length
# -> line_slope 0.5555555555555556 Intercept 49.55555555555554 length
# -> line_slope -0.2727272727272727 Intercept 510.09090909090907 length
# -> line_slope 0.6111111111111112 Intercept 20.833333333333314 length
# -> line_slope 0.5 Intercept 112.5 length
# -> line_slope 0.75 Intercept -91.25 length
# -> line_slope 0.6666666666666666 Intercept -20.66666666666663 length
# -> line_slope 0.8 Intercept -119.20000000000005 length
# ==============================FINAL COUNT 5 20
# =====>Average  line_slope 0.6986165767067469 Intercept -44.094311095036716 length
# =====>Average  line_slope -0.724367816091954 Intercept 655.2387848932676 length

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image,kernel_size=9,
                  low_canny_threshold=140,
                  high_canny_threshold=200,
                  min_hough_line=5,
                 max_hough_gap=3):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    
    #turn to gray
    #copy_img=np.copy(image)
    gray=grayscale(image)


    #smooth image 
    blur_gray=gaussian_blur(gray,kernel_size)

    #apply Canny
    edges=canny(blur_gray, low_canny_threshold, high_canny_threshold)

    #get region of interest
    #x_size=image.shape[1]
    y_size=image.shape[0]
    vertices=np.array([[(120,y_size),(905,y_size),(510,320),(450,320)]], dtype=np.int32)
    masked_edges=region_of_interest(edges, vertices)

    #Hough lines
    #print ('type',masked_edges.shape)
    line_image=hough_lines(masked_edges, rho=1, theta=np.pi/180, threshold=1, min_line_len=min_hough_line, max_line_gap=max_hough_gap)

    # Create a "color" binary image to combine with line image
    #color_edges = np.dstack((edges, edges, edges))

    # Draw the lines on the edge image
    result = cv2.addWeighted(image, 0.8, line_image, 0.2, 0)
    
    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# t:  93%|█████████▎| 632/681 [00:59<00:01, 47.38it/s, now=None]
# t:   0%|          | 0/221 [00:00<?, ?it/s, now=None]
# t:   2%|▏         | 5/221 [00:00<00:04, 47.65it/s, now=None]
# ==============================FINAL COUNT 11 27
# Moviepy - Building video test_videos_output/solidWhiteRight.mp4.
# Moviepy - Writing video test_videos_output/solidWhiteRight.mp4
#
# ==============================FINAL COUNT 11 27
# ==============================FINAL COUNT 12 22
# ==============================FINAL COUNT 16 29
# ==============================FINAL COUNT 13 22
# ==============================FINAL COUNT 9 28
# ==============================FINAL COUNT 8 23
# ==============================FINAL COUNT 7 29
# ==============================FINAL COUNT 7 31
# ==============================FINAL COUNT 7
# t:   6%|▋         | 14/221 [00:00<00:02, 69.68it/s, now=None]
# t:  10%|█         | 23/221 [00:00<00:02, 75.05it/s, now=None]
#  22
# ==============================FINAL COUNT 8 30
# ==============================FINAL COUNT 11 23
# ==============================FINAL COUNT 15 24
# ==============================FINAL COUNT 16 18
# ==============================FINAL COUNT 16 16
# ==============================FINAL COUNT 13 20
# ==============================FINAL COUNT 15 30
# ==============================FINAL COUNT 9 25
# ==============================FINAL COUNT 6 32
# ==============================FINAL COUNT 8 18
# ==============================FINAL COUNT 8 24
# ==============================FINAL COUNT 9 27
# ==============================FINAL COUNT 9 26
# ==============================FINAL COUNT 10 33
# ==============================FINAL COUNT 9 25
# ==============================FINAL COUNT 8 29
# t:  14%|█▍        | 32/221 [00:00<00:02, 78.34it/s, now=None]
# t:  19%|█▊        | 41/221 [00:00<00:02, 79.89it/s, now=None]
# ==============================FINAL COUNT 17 25
# ==============================FINAL COUNT 13 21
# ==============================FINAL COUNT 13 17
# ==============================FINAL COUNT 8 26
# ==============================FINAL COUNT 8 28
# ==============================FINAL COUNT 8 23
# ==============================FINAL COUNT 6 21
# ==============================FINAL COUNT 9 31
# ==============================FINAL COUNT 11 18
# ==============================FINAL COUNT 10 25
# ==============================FINAL COUNT 9 24
# ==============================FINAL COUNT 17 28
# ==============================FINAL COUNT 18 17
# ==============================FINAL COUNT 16 24
# ==============================FINAL COUNT 13 22
# ==============================FINAL COUNT 10 25
# ==============================FINAL COUNT 7 18
# t:  22%|██▏       | 49/221 [00:00<00:02, 59.45it/s, now=None]
# ==============================FINAL COUNT 7 25
# ==============================FINAL COUNT 7 33
# ==============================FINAL COUNT 8 27
# ==============================FINAL COUNT 10 22
# ==============================FINAL COUNT 6 29
# ==============================FINAL COUNT 12 35
# ==============================FINAL COUNT 12 29
# t:  25%|██▌       | 56/221 [00:00<00:02, 55.50it/s, now=None]
# ==============================FINAL COUNT 17 14
# ==============================FINAL COUNT 15 24
# ==============================FINAL COUNT 13 32
# ==============================FINAL COUNT 9 33
# ==============================FINAL COUNT 10 31
# ==============================FINAL COUNT 5 36
# ==============================FINAL COUNT 6 20
# ==============================FINAL COUNT 10 27
# ==============================FINAL COUNT 12 35
# ==============================FINAL COUNT 10 16
# ==============================FINAL COUNT 16
# t:  28%|██▊       | 62/221 [00:01<00:03, 52.97it/s, now=None]
# t:  31%|███       | 68/221 [00:01<00:02, 52.51it/s, now=None]
#  25
# ==============================FINAL COUNT 21 23
# ==============================FINAL COUNT 19 34
# ==============================FINAL COUNT 17 25
# ==============================FINAL COUNT 15 23
# ==============================FINAL COUNT 9 34
# ==============================FINAL COUNT 7 34
# ==============================FINAL COUNT 7 28
# ==============================FINAL COUNT 7 25
# ==============================FINAL COUNT 8 33
# ==============================FINAL COUNT 7 27
# t:  33%|███▎      | 74/221 [00:01<00:02, 49.76it/s, now=None]
# ==============================FINAL COUNT 11 34
# ==============================FINAL COUNT 8 19
# ==============================FINAL COUNT 11 27
# ==============================FINAL COUNT 27 29
# ==============================FINAL COUNT 14 23
# ==============================FINAL COUNT 12 42
# ==============================FINAL COUNT 10 25
# ==============================FINAL COUNT 8 34
# ==============================FINAL COUNT 6 16
# t:  36%|███▌      | 80/221 [00:01<00:02, 48.02it/s, now=None]
# t:  38%|███▊      | 85/221 [00:01<00:03, 44.77it/s, now=None]
# ==============================FINAL COUNT 10 24
# ==============================FINAL COUNT 7 32
# ==============================FINAL COUNT 5 36
# ==============================FINAL COUNT 9 35
# ==============================FINAL COUNT 7 33
# ==============================FINAL COUNT 8 38
# ==============================FINAL COUNT 13 21
# ==============================FINAL COUNT 13 33
# ==============================FINAL COUNT 16 15
# t:  42%|████▏     | 92/221 [00:01<00:02, 48.69it/s, now=None]
# t:  44%|████▍     | 97/221 [00:01<00:02, 47.83it/s, now=None]
# ==============================FINAL COUNT 9 37
# ==============================FINAL COUNT 10 20
# ==============================FINAL COUNT 9 29
# ==============================FINAL COUNT 8 26
# ==============================FINAL COUNT 7 38
# ==============================FINAL COUNT 9 33
# ==============================FINAL COUNT 11 21
# ==============================FINAL COUNT 12 31
# ==============================FINAL COUNT 14 23
# ==============================FINAL COUNT 11 15
# ==============================FINAL COUNT 8 31
# t:  46%|████▌     | 102/221 [00:01<00:02, 46.36it/s, now=None]
# ==============================FINAL COUNT 12 22
# ==============================FINAL COUNT 14 26
# ==============================FINAL COUNT 6 22
# ==============================FINAL COUNT 10 13
# ==============================FINAL COUNT 8 28
# ==============================FINAL COUNT 10 29
# ==============================FINAL COUNT 11 29
# ==============================FINAL COUNT 13 35
# ==============================FINAL COUNT 14 32
# t:  49%|████▉     | 109/221 [00:02<00:02, 48.49it/s, now=None]
# t:  52%|█████▏    | 114/221 [00:02<00:02, 47.08it/s, now=None]
# ==============================FINAL COUNT 20 24
# ==============================FINAL COUNT 16 24
# ==============================FINAL COUNT 20 8
# ==============================FINAL COUNT 16 29
# ==============================FINAL COUNT 18 24
# ==============================FINAL COUNT 8 29
# ==============================FINAL COUNT 8 32
# ==============================FINAL COUNT 7 22
# ==============================FINAL COUNT 7 21
# ==============================FINAL COUNT 9 29
# ==============================FINAL COUNT 8 28
# t:  55%|█████▍    | 121/221 [00:02<00:02, 49.82it/s, now=None]
# t:  57%|█████▋    | 127/221 [00:02<00:01, 52.33it/s, now=None]
# ==============================FINAL COUNT 13 30
# ==============================FINAL COUNT 16 18
# ==============================FINAL COUNT 20 19
# ==============================FINAL COUNT 15 23
# ==============================FINAL COUNT 13 26
# ==============================FINAL COUNT 14 19
# ==============================FINAL COUNT 9 34
# ==============================FINAL COUNT 7 26
# ==============================FINAL COUNT 9 11
# t:  60%|██████    | 133/221 [00:02<00:01, 50.46it/s, now=None]
# t:  63%|██████▎   | 139/221 [00:02<00:01, 50.21it/s, now=None]
# ==============================FINAL COUNT 8 22
# ==============================FINAL COUNT 12 26
# ==============================FINAL COUNT 5 32
# ==============================FINAL COUNT 12 10
# ==============================FINAL COUNT 17 16
# ==============================FINAL COUNT 16 16
# ==============================FINAL COUNT 12 25
# ==============================FINAL COUNT 13 32
# ==============================FINAL COUNT 14 22
# ==============================FINAL COUNT 6 22
# t:  66%|██████▌   | 145/221 [00:02<00:01, 48.70it/s, now=None]
# ==============================FINAL COUNT 6 23
# ==============================FINAL COUNT 8 23
# ==============================FINAL COUNT 9 31
# ==============================FINAL COUNT 9 14
# ==============================FINAL COUNT 9 14
# ==============================FINAL COUNT 11 21
# ==============================FINAL COUNT 14 22
# ==============================FINAL COUNT 19 28
# ==============================FINAL COUNT 10 32
# ==============================FINAL COUNT 14 33
# t:  68%|██████▊   | 150/221 [00:02<00:01, 45.20it/s, now=None]
# t:  71%|███████   | 156/221 [00:02<00:01, 48.22it/s, now=None]
# ==============================FINAL COUNT 7 15
# ==============================FINAL COUNT 7 30
# ==============================FINAL COUNT 7 26
# ==============================FINAL COUNT 4 28
# ==============================FINAL COUNT 7 18
# ==============================FINAL COUNT 11 30
# ==============================FINAL COUNT 8 27
# ==============================FINAL COUNT 14 33
# ==============================FINAL COUNT 11
# t:  73%|███████▎  | 161/221 [00:03<00:01, 44.49it/s, now=None]
# t:  75%|███████▌  | 166/221 [00:03<00:01, 44.88it/s, now=None]
# 17
# ==============================FINAL COUNT 10 33
# ==============================FINAL COUNT 19 22
# ==============================FINAL COUNT 16 19
# ==============================FINAL COUNT 11 26
# ==============================FINAL COUNT 6 24
# ==============================FINAL COUNT 6 26
# ==============================FINAL COUNT 6 24
# ==============================FINAL COUNT 7 12
# ==============================FINAL COUNT 10 13
# ==============================FINAL COUNT 10 19
# ==============================FINAL COUNT 10 26
# t:  78%|███████▊  | 172/221 [00:03<00:01, 48.23it/s, now=None]
# t:  80%|████████  | 177/221 [00:03<00:00, 46.82it/s, now=None]
# ==============================FINAL COUNT 12 9
# ==============================FINAL COUNT 14 7
# ==============================FINAL COUNT 18 14
# ==============================FINAL COUNT 13 23
# ==============================FINAL COUNT 4 26
# ==============================FINAL COUNT 5 34
# ==============================FINAL COUNT 9 19
# ==============================FINAL COUNT 7 32
# ==============================FINAL COUNT 10 15
# ==============================FINAL COUNT 10 27
# ==============================FINAL COUNT 7 29
# t:  82%|████████▏ | 182/221 [00:03<00:00, 45.01it/s, now=None]
# t:  85%|████████▌ | 188/221 [00:03<00:00, 46.77it/s, now=None]
# ==============================FINAL COUNT 9 14
# ==============================FINAL COUNT 10 30
# ==============================FINAL COUNT 12 20
# ==============================FINAL COUNT 12 19
# ==============================FINAL COUNT 12 20
# ==============================FINAL COUNT 10 28
# ==============================FINAL COUNT 5 17
# ==============================FINAL COUNT 7 12
# ==============================FINAL COUNT 11 15
# t:  87%|████████▋ | 193/221 [00:03<00:00, 46.89it/s, now=None]
# ==============================FINAL COUNT 5 13
# ==============================FINAL COUNT 7 16
# ==============================FINAL COUNT 9 6
# ==============================FINAL COUNT 9 14
# ==============================FINAL COUNT 9 20
# ==============================FINAL COUNT 13 25
# ==============================FINAL COUNT 10 26
# ==============================FINAL COUNT 11 18
# ==============================FINAL COUNT 11 27
# t:  90%|████████▉ | 198/221 [00:03<00:00, 45.75it/s, now=None]
# t:  92%|█████████▏| 204/221 [00:04<00:00, 48.07it/s, now=None]
# ==============================FINAL COUNT 5 32
# ==============================FINAL COUNT 4 22
# ==============================FINAL COUNT 6 24
# ==============================FINAL COUNT 8 17
# ==============================FINAL COUNT 10 25
# ==============================FINAL COUNT 7 21
# ==============================FINAL COUNT 11 23
# ==============================FINAL COUNT 14 21
# ==============================FINAL COUNT 13 8
# ==============================FINAL COUNT 11 11
# t:  95%|█████████▍| 209/221 [00:04<00:00, 43.28it/s, now=None]
# t:  98%|█████████▊| 216/221 [00:04<00:00, 49.30it/s, now=None]
# ==============================FINAL COUNT 11 11
# ==============================FINAL COUNT 9 7
# ==============================FINAL COUNT 6 16
# ==============================FINAL COUNT 6 14
# ==============================FINAL COUNT 4 27
# ==============================FINAL COUNT 7 13
# ==============================FINAL COUNT 7 17
# ==============================FINAL COUNT 8 18
# ==============================FINAL COUNT 11 16
# ==============================FINAL COUNT 9 7
# ==============================FINAL COUNT 12 14
# ==============================FINAL COUNT 14 17
# ==============================FINAL COUNT 14 11
# ==============================FINAL COUNT 14 25
# t:  93%|█████████▎| 632/681 [01:04<00:01, 47.38it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready test_videos_output/solidWhiteRight.mp4
# Wall time: 5.02 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# t:  93%|█████████▎| 632/681 [01:16<00:01, 47.38it/s, now=None]
# t:   0%|          | 0/681 [00:00<?, ?it/s, now=None]
# t:   1%|          | 6/681 [00:00<00:12, 55.59it/s, now=None]
# ==============================FINAL COUNT 13 12
# Moviepy - Building video test_videos_output/solidYellowLeft.mp4.
# Moviepy - Writing video test_videos_output/solidYellowLeft.mp4
#
# ==============================FINAL COUNT 13 12
# ==============================FINAL COUNT 10 22
# ==============================FINAL COUNT 21 15
# ==============================FINAL COUNT 26 13
# ==============================FINAL COUNT 18 12
# ==============================FINAL COUNT 19 7
# ==============================FINAL COUNT 18 6
# ==============================FINAL COUNT 25 7
# ==============================FINAL COUNT 27 9
# ==============================FINAL COUNT 10 7
# t:   2%|▏         | 15/681 [00:00<00:09, 71.16it/s, now=None]
# t:   4%|▎         | 24/681 [00:00<00:08, 77.04it/s, now=None]
# ==============================FINAL COUNT 12 8
# ==============================FINAL COUNT 26 11
# ==============================FINAL COUNT 24 12
# ==============================FINAL COUNT 27 19
# ==============================FINAL COUNT 29 19
# ==============================FINAL COUNT 10 18
# ==============================FINAL COUNT 16 13
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 22 8
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 14 8
# ==============================FINAL COUNT 19 11
# ==============================FINAL COUNT 22 7
# ==============================FINAL COUNT 27 9
# ==============================FINAL COUNT 24 10
# ==============================FINAL COUNT 34 16
# t:   5%|▍         | 33/681 [00:00<00:08, 79.54it/s, now=None]
# t:   6%|▌         | 41/681 [00:00<00:08, 78.90it/s, now=None]
# ==============================FINAL COUNT 25 15
# ==============================FINAL COUNT 27 13
# ==============================FINAL COUNT 14 12
# ==============================FINAL COUNT 26 8
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 23 4
# ==============================FINAL COUNT 18 6
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 21 6
# ==============================FINAL COUNT 28 5
# ==============================FINAL COUNT 29 9
# ==============================FINAL COUNT 30 13
# ==============================FINAL COUNT 19 15
# ==============================FINAL COUNT 23 12
# ==============================FINAL COUNT 17 13
# ==============================FINAL COUNT 14 14
# t:   7%|▋         | 49/681 [00:00<00:11, 57.09it/s, now=None]
# ==============================FINAL COUNT 31 12
# ==============================FINAL COUNT 11 6
# ==============================FINAL COUNT 27 6
# ==============================FINAL COUNT 16 10
# ==============================FINAL COUNT 21 8
# ==============================FINAL COUNT 26 7
# ==============================FINAL COUNT 20 11
# t:   8%|▊         | 56/681 [00:00<00:11, 55.09it/s, now=None]
# ==============================FINAL COUNT 37 16
# ==============================FINAL COUNT 21 11
# ==============================FINAL COUNT 25 15
# ==============================FINAL COUNT 24 7
# ==============================FINAL COUNT 19 18
# ==============================FINAL COUNT 17 8
# ==============================FINAL COUNT 28 4
# ==============================FINAL COUNT 13 7
# ==============================FINAL COUNT 28 6
# t:   9%|▉         | 63/681 [00:01<00:12, 49.91it/s, now=None]
# t:  10%|█         | 69/681 [00:01<00:12, 48.97it/s, now=None]
# ==============================FINAL COUNT 25 5
# ==============================FINAL COUNT 22 7
# ==============================FINAL COUNT 25 9
# ==============================FINAL COUNT 30 12
# ==============================FINAL COUNT 34 13
# ==============================FINAL COUNT 20 16
# ==============================FINAL COUNT 20 25
# ==============================FINAL COUNT 28 12
# ==============================FINAL COUNT 29 12
# ==============================FINAL COUNT 25 9
# t:  11%|█         | 75/681 [00:01<00:12, 47.65it/s, now=None]
# ==============================FINAL COUNT 8 7
# ==============================FINAL COUNT 22 5
# ==============================FINAL COUNT 26 9
# ==============================FINAL COUNT 26 8
# ==============================FINAL COUNT 21 10
# ==============================FINAL COUNT 27 10
# ==============================FINAL COUNT 16 8
# ==============================FINAL COUNT 32 15
# ==============================FINAL COUNT 28 20
# ==============================FINAL COUNT 19 16
# t:  12%|█▏        | 81/681 [00:01<00:12, 48.96it/s, now=None]
# ==============================FINAL COUNT 20 14
# ==============================FINAL COUNT 23 12
# ==============================FINAL COUNT 34 7
# ==============================FINAL COUNT 20 10
# ==============================FINAL COUNT 20 6
# ==============================FINAL COUNT 31 7
# ==============================FINAL COUNT 28 7
# ==============================FINAL COUNT 25 11
# t:  13%|█▎        | 87/681 [00:01<00:13, 43.34it/s, now=None]
# t:  14%|█▎        | 93/681 [00:01<00:13, 44.51it/s, now=None]
# ==============================FINAL COUNT 33 12
# ==============================FINAL COUNT 18 19
# ==============================FINAL COUNT 23 14
# ==============================FINAL COUNT 28 21
# ==============================FINAL COUNT 29 17
# ==============================FINAL COUNT 15 15
# ==============================FINAL COUNT 21 8
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 24 9
# t:  14%|█▍        | 98/681 [00:01<00:13, 43.56it/s, now=None]
# t:  15%|█▌        | 103/681 [00:01<00:13, 44.37it/s, now=None]
# ==============================FINAL COUNT 34 6
# ==============================FINAL COUNT 10 9
# ==============================FINAL COUNT 33 7
# ==============================FINAL COUNT 32 10
# ==============================FINAL COUNT 26 11
# ==============================FINAL COUNT 12 13
# ==============================FINAL COUNT 28 11
# ==============================FINAL COUNT 19 21
# ==============================FINAL COUNT 9 17
# ==============================FINAL COUNT 32
# t:  16%|█▌        | 108/681 [00:02<00:12, 45.69it/s, now=None]
#  13
# ==============================FINAL COUNT 26 14
# ==============================FINAL COUNT 28 4
# ==============================FINAL COUNT 26 5
# ==============================FINAL COUNT 19 7
# ==============================FINAL COUNT 26 8
# ==============================FINAL COUNT 31 7
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 31 13
# t:  17%|█▋        | 114/681 [00:02<00:13, 42.80it/s, now=None]
# t:  18%|█▊        | 120/681 [00:02<00:12, 46.37it/s, now=None]
# ==============================FINAL COUNT 32 12
# ==============================FINAL COUNT 24 16
# ==============================FINAL COUNT 20 15
# ==============================FINAL COUNT 30 20
# ==============================FINAL COUNT 27 14
# ==============================FINAL COUNT 10 8
# ==============================FINAL COUNT 7 5
# ==============================FINAL COUNT 20 9
# ==============================FINAL COUNT 13 5
# ==============================FINAL COUNT 12 8
# ==============================FINAL COUNT 17 10
# ==============================FINAL COUNT 16 11
# t:  19%|█▊        | 126/681 [00:02<00:12, 45.87it/s, now=None]
# t:  19%|█▉        | 132/681 [00:02<00:11, 49.21it/s, now=None]
# ==============================FINAL COUNT 10 11
# ==============================FINAL COUNT 14 16
# ==============================FINAL COUNT 5 21
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 28 10
# ==============================FINAL COUNT 20 10
# ==============================FINAL COUNT 24 7
# ==============================FINAL COUNT 25 4
# ==============================FINAL COUNT 17 5
# ==============================FINAL COUNT 13 5
# ==============================FINAL COUNT 20 8
# t:  20%|██        | 138/681 [00:02<00:11, 46.75it/s, now=None]
# t:  21%|██        | 143/681 [00:02<00:11, 46.41it/s, now=None]
# ==============================FINAL COUNT 17 8
# ==============================FINAL COUNT 29 14
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 10 16
# ==============================FINAL COUNT 26 17
# ==============================FINAL COUNT 19 21
# ==============================FINAL COUNT 35 10
# ==============================FINAL COUNT 15 8
# ==============================FINAL COUNT 24 2
# ==============================FINAL COUNT 19 6
# t:  22%|██▏       | 150/681 [00:02<00:10, 49.11it/s, now=None]
# t:  23%|██▎       | 155/681 [00:03<00:10, 48.72it/s, now=None]
# ==============================FINAL COUNT 28 5
# ==============================FINAL COUNT 24 9
# ==============================FINAL COUNT 24 8
# ==============================FINAL COUNT 9 6
# ==============================FINAL COUNT 27 8
# ==============================FINAL COUNT 31 14
# ==============================FINAL COUNT 31 18
# ==============================FINAL COUNT 24 10
# ==============================FINAL COUNT 28 12
# ==============================FINAL COUNT 22 9
# ==============================FINAL COUNT 21 4
# t:  23%|██▎       | 160/681 [00:03<00:10, 48.04it/s, now=None]
# t:  24%|██▍       | 165/681 [00:03<00:11, 45.84it/s, now=None]
# ==============================FINAL COUNT 30 4
# ==============================FINAL COUNT 30 6
# ==============================FINAL COUNT 22 8
# ==============================FINAL COUNT 22 10
# ==============================FINAL COUNT 28 7
# ==============================FINAL COUNT 23 7
# ==============================FINAL COUNT 12 11
# ==============================FINAL COUNT 29 5
# ==============================FINAL COUNT 25 14
# t:  25%|██▍       | 170/681 [00:03<00:11, 43.04it/s, now=None]
# ==============================FINAL COUNT 25 9
# ==============================FINAL COUNT 22 9
# ==============================FINAL COUNT 30 5
# ==============================FINAL COUNT 32 3
# ==============================FINAL COUNT 29 7
# ==============================FINAL COUNT 20 5
# ==============================FINAL COUNT 28 6
# ==============================FINAL COUNT 34 7
# ==============================FINAL COUNT 25 7
# t:  26%|██▌       | 176/681 [00:03<00:10, 46.73it/s, now=None]
# t:  27%|██▋       | 181/681 [00:03<00:11, 44.85it/s, now=None]
# ==============================FINAL COUNT 21 13
# ==============================FINAL COUNT 20 10
# ==============================FINAL COUNT 19 18
# ==============================FINAL COUNT 18 11
# ==============================FINAL COUNT 23 12
# ==============================FINAL COUNT 23 11
# ==============================FINAL COUNT 17 1
# ==============================FINAL COUNT 25 4
# ==============================FINAL COUNT 17 3
# t:  27%|██▋       | 186/681 [00:03<00:11, 44.91it/s, now=None]
# t:  28%|██▊       | 191/681 [00:03<00:11, 44.04it/s, now=None]
# ==============================FINAL COUNT 28 8
# ==============================FINAL COUNT 12 7
# ==============================FINAL COUNT 16 4
# ==============================FINAL COUNT 22 10
# ==============================FINAL COUNT 20 16
# ==============================FINAL COUNT 18 13
# ==============================FINAL COUNT 24 11
# ==============================FINAL COUNT 19 15
# ==============================FINAL COUNT 25 4
# t:  29%|██▉       | 196/681 [00:03<00:10, 45.40it/s, now=None]
# t:  30%|██▉       | 201/681 [00:04<00:11, 43.22it/s, now=None]
# ==============================FINAL COUNT 11 3
# ==============================FINAL COUNT 21 1
# ==============================FINAL COUNT 27 5
# ==============================FINAL COUNT 18 7
# ==============================FINAL COUNT 20 5
# ==============================FINAL COUNT 19 7
# ==============================FINAL COUNT 24 9
# ==============================FINAL COUNT 28 10
# ==============================FINAL COUNT 24 11
# t:  30%|███       | 206/681 [00:04<00:10, 43.20it/s, now=None]
# t:  31%|███       | 212/681 [00:04<00:10, 45.28it/s, now=None]
# ==============================FINAL COUNT 24 11
# ==============================FINAL COUNT 31 14
# ==============================FINAL COUNT 26 8
# ==============================FINAL COUNT 24 8
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 23 8
# ==============================FINAL COUNT 21 2
# ==============================FINAL COUNT 22 3
# ==============================FINAL COUNT 23 4
# t:  32%|███▏      | 218/681 [00:04<00:10, 44.69it/s, now=None]
# ==============================FINAL COUNT 22 6
# ==============================FINAL COUNT 14 10
# ==============================FINAL COUNT 28 15
# ==============================FINAL COUNT 25 19
# ==============================FINAL COUNT 21 9
# ==============================FINAL COUNT 20 12
# ==============================FINAL COUNT 17 11
# ==============================FINAL COUNT 28 8
# ==============================FINAL COUNT 24 2
# ==============================FINAL COUNT 22 8
# t:  33%|███▎      | 225/681 [00:04<00:09, 46.98it/s, now=None]
# ==============================FINAL COUNT 26 7
# ==============================FINAL COUNT 25 4
# ==============================FINAL COUNT 16 6
# ==============================FINAL COUNT 15 6
# ==============================FINAL COUNT 31 12
# ==============================FINAL COUNT 27 12
# ==============================FINAL COUNT 21 14
# ==============================FINAL COUNT 21 10
# ==============================FINAL COUNT 15 9
# ==============================FINAL COUNT 21 7
# t:  34%|███▍      | 232/681 [00:04<00:09, 48.51it/s, now=None]
# t:  35%|███▍      | 238/681 [00:04<00:08, 50.37it/s, now=None]
# ==============================FINAL COUNT 22 7
# ==============================FINAL COUNT 19 8
# ==============================FINAL COUNT 15 6
# ==============================FINAL COUNT 31 6
# ==============================FINAL COUNT 21 12
# ==============================FINAL COUNT 20 3
# ==============================FINAL COUNT 15 11
# ==============================FINAL COUNT 18 15
# ==============================FINAL COUNT 20 22
# ==============================FINAL COUNT 25 9
# t:  36%|███▌      | 244/681 [00:04<00:08, 49.30it/s, now=None]
# t:  37%|███▋      | 249/681 [00:05<00:09, 47.90it/s, now=None]
# ==============================FINAL COUNT 31 12
# ==============================FINAL COUNT 32 10
# ==============================FINAL COUNT 30 1
# ==============================FINAL COUNT 18 5
# ==============================FINAL COUNT 17 7
# ==============================FINAL COUNT 34 3
# ==============================FINAL COUNT 21 6
# ==============================FINAL COUNT 26 5
# ==============================FINAL COUNT 29 8
# ==============================FINAL COUNT 30 7
# ==============================FINAL COUNT 30 10
# ==============================FINAL COUNT 20 13
# t:  37%|███▋      | 255/681 [00:05<00:09, 46.68it/s, now=None]
# t:  38%|███▊      | 261/681 [00:05<00:09, 46.09it/s, now=None]
# ==============================FINAL COUNT 16 14
# ==============================FINAL COUNT 30 13
# ==============================FINAL COUNT 20 12
# ==============================FINAL COUNT 16 8
# ==============================FINAL COUNT 22 5
# ==============================FINAL COUNT 36 7
# ==============================FINAL COUNT 36 6
# ==============================FINAL COUNT 11 8
# ==============================FINAL COUNT 29 5
# t:  39%|███▉      | 267/681 [00:05<00:08, 49.09it/s, now=None]
# t:  40%|████      | 273/681 [00:05<00:08, 48.29it/s, now=None]
# ==============================FINAL COUNT 26 5
# ==============================FINAL COUNT 8 6
# ==============================FINAL COUNT 14 12
# ==============================FINAL COUNT 25 14
# ==============================FINAL COUNT 30 16
# ==============================FINAL COUNT 14 17
# ==============================FINAL COUNT 25 10
# ==============================FINAL COUNT 21 8
# ==============================FINAL COUNT 22 6
# ==============================FINAL COUNT 21 6
# ==============================FINAL COUNT
# t:  41%|████      | 278/681 [00:05<00:08, 46.69it/s, now=None]
# 23 5
# ==============================FINAL COUNT 17 6
# ==============================FINAL COUNT 22 4
# ==============================FINAL COUNT 29 7
# ==============================FINAL COUNT 19 6
# ==============================FINAL COUNT 21 12
# ==============================FINAL COUNT 23 15
# ==============================FINAL COUNT 28 13
# ==============================FINAL COUNT 23 18
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 19 2
# t:  42%|████▏     | 284/681 [00:05<00:07, 49.78it/s, now=None]
# t:  43%|████▎     | 290/681 [00:05<00:08, 48.49it/s, now=None]
# ==============================FINAL COUNT 22 5
# ==============================FINAL COUNT 21 2
# ==============================FINAL COUNT 13 7
# ==============================FINAL COUNT 17 6
# ==============================FINAL COUNT 13 8
# ==============================FINAL COUNT 10 9
# ==============================FINAL COUNT 6 12
# ==============================FINAL COUNT 15 17
# ==============================FINAL COUNT 15 15
# ==============================FINAL COUNT 8 13
# t:  43%|████▎     | 295/681 [00:06<00:08, 48.02it/s, now=None]
# t:  44%|████▍     | 300/681 [00:06<00:07, 48.04it/s, now=None]
# ==============================FINAL COUNT 18 8
# ==============================FINAL COUNT 10 6
# ==============================FINAL COUNT 18 3
# ==============================FINAL COUNT 20 2
# ==============================FINAL COUNT 20 4
# ==============================FINAL COUNT 21 7
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 9 9
# ==============================FINAL COUNT 11 14
# ==============================FINAL COUNT 7 6
# t:  45%|████▌     | 307/681 [00:06<00:07, 50.88it/s, now=None]
# t:  46%|████▌     | 313/681 [00:06<00:07, 50.62it/s, now=None]
# ==============================FINAL COUNT 17 20
# ==============================FINAL COUNT 29 14
# ==============================FINAL COUNT 15 16
# ==============================FINAL COUNT 24 8
# ==============================FINAL COUNT 10 3
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 32 4
# ==============================FINAL COUNT 30 6
# ==============================FINAL COUNT 22 8
# ==============================FINAL COUNT 25 9
# ==============================FINAL COUNT 18 9
# t:  47%|████▋     | 319/681 [00:06<00:07, 47.42it/s, now=None]
# ==============================FINAL COUNT 26 11
# ==============================FINAL COUNT 23 16
# ==============================FINAL COUNT 24 12
# ==============================FINAL COUNT 27 13
# ==============================FINAL COUNT 20 9
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 26 4
# ==============================FINAL COUNT 8 3
# ==============================FINAL COUNT 15 5
# t:  48%|████▊     | 324/681 [00:06<00:07, 46.78it/s, now=None]
# t:  48%|████▊     | 329/681 [00:06<00:08, 42.92it/s, now=None]
# ==============================FINAL COUNT 8 9
# ==============================FINAL COUNT 21 8
# ==============================FINAL COUNT 16 7
# ==============================FINAL COUNT 26 11
# ==============================FINAL COUNT 12 15
# ==============================FINAL COUNT 17 12
# ==============================FINAL COUNT 16 14
# ==============================FINAL COUNT 10 4
# ==============================FINAL COUNT 14 6
# ==============================FINAL COUNT 31 8
# t:  49%|████▉     | 335/681 [00:06<00:07, 44.96it/s, now=None]
# t:  50%|█████     | 341/681 [00:07<00:07, 48.07it/s, now=None]
# ==============================FINAL COUNT 26 7
# ==============================FINAL COUNT 9 11
# ==============================FINAL COUNT 12 10
# ==============================FINAL COUNT 9 7
# ==============================FINAL COUNT 22 8
# ==============================FINAL COUNT 30 11
# ==============================FINAL COUNT 22 13
# ==============================FINAL COUNT 17 12
# ==============================FINAL COUNT 22
# t:  51%|█████     | 347/681 [00:07<00:06, 48.54it/s, now=None]
#  15
# ==============================FINAL COUNT 25 12
# ==============================FINAL COUNT 20 4
# ==============================FINAL COUNT 25 6
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 28 10
# ==============================FINAL COUNT 26 6
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 30 12
# ==============================FINAL COUNT 34 9
# t:  52%|█████▏    | 352/681 [00:07<00:07, 44.80it/s, now=None]
# t:  53%|█████▎    | 358/681 [00:07<00:06, 47.85it/s, now=None]
# ==============================FINAL COUNT 19 19
# ==============================FINAL COUNT 29 15
# ==============================FINAL COUNT 18 15
# ==============================FINAL COUNT 22 5
# ==============================FINAL COUNT 25 2
# ==============================FINAL COUNT 28 4
# ==============================FINAL COUNT 33 5
# ==============================FINAL COUNT 14 8
# ==============================FINAL COUNT 23 5
# ==============================FINAL COUNT 39 9
# ==============================FINAL COUNT 33 10
# t:  53%|█████▎    | 363/681 [00:07<00:06, 46.58it/s, now=None]
# t:  54%|█████▍    | 368/681 [00:07<00:07, 41.72it/s, now=None]
# ==============================FINAL COUNT 24 14
# ==============================FINAL COUNT 26 13
# ==============================FINAL COUNT 25 13
# ==============================FINAL COUNT 22 17
# ==============================FINAL COUNT 33 11
# ==============================FINAL COUNT 25 4
# ==============================FINAL COUNT 26 5
# ==============================FINAL COUNT 13 4
# ==============================FINAL COUNT 20 5
# t:  55%|█████▍    | 374/681 [00:07<00:06, 46.08it/s, now=None]
# t:  56%|█████▌    | 379/681 [00:07<00:06, 44.99it/s, now=None]
# ==============================FINAL COUNT 32 8
# ==============================FINAL COUNT 31 6
# ==============================FINAL COUNT 28 11
# ==============================FINAL COUNT 17 9
# ==============================FINAL COUNT 21 18
# ==============================FINAL COUNT 26 16
# ==============================FINAL COUNT 26 19
# ==============================FINAL COUNT 12 11
# ==============================FINAL COUNT 22 6
# ==============================FINAL COUNT 21 8
# t:  57%|█████▋    | 386/681 [00:08<00:06, 47.81it/s, now=None]
# ==============================FINAL COUNT 28 5
# ==============================FINAL COUNT 16 9
# ==============================FINAL COUNT 33 12
# ==============================FINAL COUNT 35 8
# ==============================FINAL COUNT 23 7
# ==============================FINAL COUNT 28 12
# ==============================FINAL COUNT 26 12
# ==============================FINAL COUNT 29 14
# ==============================FINAL COUNT 24 14
# ==============================FINAL COUNT 23 11
# t:  58%|█████▊    | 392/681 [00:08<00:05, 48.59it/s, now=None]
# t:  58%|█████▊    | 397/681 [00:08<00:06, 47.24it/s, now=None]
# ==============================FINAL COUNT 19 5
# ==============================FINAL COUNT 26 7
# ==============================FINAL COUNT 18 8
# ==============================FINAL COUNT 15 5
# ==============================FINAL COUNT 31 7
# ==============================FINAL COUNT 9 10
# ==============================FINAL COUNT 24 8
# ==============================FINAL COUNT 20 8
# ==============================FINAL COUNT 38 14
# ==============================FINAL COUNT
# t:  59%|█████▉    | 402/681 [00:08<00:05, 46.86it/s, now=None]
# t:  60%|█████▉    | 407/681 [00:08<00:06, 43.39it/s, now=None]
# 24 19
# ==============================FINAL COUNT 30 18
# ==============================FINAL COUNT 32 11
# ==============================FINAL COUNT 25 12
# ==============================FINAL COUNT 10 6
# ==============================FINAL COUNT 27 8
# ==============================FINAL COUNT 24 9
# ==============================FINAL COUNT 28 11
# ==============================FINAL COUNT 24 14
# t:  61%|██████    | 413/681 [00:08<00:05, 46.04it/s, now=None]
# ==============================FINAL COUNT 24 9
# ==============================FINAL COUNT 15 6
# ==============================FINAL COUNT 31 14
# ==============================FINAL COUNT 25 19
# ==============================FINAL COUNT 16 16
# ==============================FINAL COUNT 28 15
# ==============================FINAL COUNT 32 12
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 29 5
# t:  62%|██████▏   | 419/681 [00:08<00:05, 44.98it/s, now=None]
# t:  62%|██████▏   | 425/681 [00:08<00:05, 47.48it/s, now=None]
# ==============================FINAL COUNT 34 7
# ==============================FINAL COUNT 19 8
# ==============================FINAL COUNT 29 9
# ==============================FINAL COUNT 30 10
# ==============================FINAL COUNT 30 8
# ==============================FINAL COUNT 33 11
# ==============================FINAL COUNT 17 12
# ==============================FINAL COUNT 19 15
# ==============================FINAL COUNT 35 12
# ==============================FINAL COUNT 30 10
# ==============================FINAL COUNT 26 7
# t:  63%|██████▎   | 430/681 [00:08<00:05, 47.16it/s, now=None]
# t:  64%|██████▍   | 435/681 [00:09<00:05, 46.92it/s, now=None]
# ==============================FINAL COUNT 35 7
# ==============================FINAL COUNT 27 7
# ==============================FINAL COUNT 13 8
# ==============================FINAL COUNT 37 5
# ==============================FINAL COUNT 31 8
# ==============================FINAL COUNT 26 12
# ==============================FINAL COUNT 31 13
# ==============================FINAL COUNT 25 7
# ==============================FINAL COUNT 26 16
# t:  65%|██████▍   | 440/681 [00:09<00:05, 43.72it/s, now=None]
# t:  65%|██████▌   | 446/681 [00:09<00:05, 46.90it/s, now=None]
# ==============================FINAL COUNT 29 13
# ==============================FINAL COUNT 32 10
# ==============================FINAL COUNT 14 3
# ==============================FINAL COUNT 20 4
# ==============================FINAL COUNT 24 5
# ==============================FINAL COUNT 18 5
# ==============================FINAL COUNT 30 9
# ==============================FINAL COUNT 27 9
# ==============================FINAL COUNT 25 7
# t:  66%|██████▌   | 451/681 [00:09<00:05, 44.74it/s, now=None]
# t:  67%|██████▋   | 456/681 [00:09<00:04, 45.18it/s, now=None]
# ==============================FINAL COUNT 32 9
# ==============================FINAL COUNT 16 8
# ==============================FINAL COUNT 32 15
# ==============================FINAL COUNT 15 21
# ==============================FINAL COUNT 34 10
# ==============================FINAL COUNT 29 12
# ==============================FINAL COUNT 16 13
# ==============================FINAL COUNT 21 7
# ==============================FINAL COUNT 22 10
# ==============================FINAL COUNT
# t:  68%|██████▊   | 461/681 [00:09<00:04, 45.15it/s, now=None]
# 26 4
# ==============================FINAL COUNT 14 6
# ==============================FINAL COUNT 18 8
# ==============================FINAL COUNT 28 9
# ==============================FINAL COUNT 21 7
# ==============================FINAL COUNT 23 12
# ==============================FINAL COUNT 9 15
# ==============================FINAL COUNT 13 17
# ==============================FINAL COUNT 18 11
# ==============================FINAL COUNT 10 6
# t:  69%|██████▊   | 467/681 [00:09<00:04, 43.83it/s, now=None]
# t:  69%|██████▉   | 472/681 [00:09<00:04, 43.85it/s, now=None]
# ==============================FINAL COUNT 37 3
# ==============================FINAL COUNT 26 4
# ==============================FINAL COUNT 32 5
# ==============================FINAL COUNT 12 7
# ==============================FINAL COUNT 19 7
# ==============================FINAL COUNT 26 10
# ==============================FINAL COUNT 32 9
# ==============================FINAL COUNT 34 15
# ==============================FINAL COUNT 13 23
# ==============================FINAL COUNT 33
# t:  70%|███████   | 478/681 [00:10<00:04, 47.22it/s, now=None]
# t:  71%|███████   | 483/681 [00:10<00:04, 45.53it/s, now=None]
# 16
# ==============================FINAL COUNT 20 7
# ==============================FINAL COUNT 21 11
# ==============================FINAL COUNT 22 4
# ==============================FINAL COUNT 22 6
# ==============================FINAL COUNT 29 8
# ==============================FINAL COUNT 17 7
# ==============================FINAL COUNT 25 8
# ==============================FINAL COUNT 16 8
# ==============================FINAL COUNT 20 12
# ==============================FINAL COUNT 23 12
# t:  72%|███████▏  | 488/681 [00:10<00:04, 43.81it/s, now=None]
# t:  73%|███████▎  | 494/681 [00:10<00:03, 46.85it/s, now=None]
# ==============================FINAL COUNT 27 7
# ==============================FINAL COUNT 26 13
# ==============================FINAL COUNT 19 22
# ==============================FINAL COUNT 21 9
# ==============================FINAL COUNT 15 10
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 25 6
# ==============================FINAL COUNT 12 6
# ==============================FINAL COUNT 29 8
# ==============================FINAL COUNT 12 5
# t:  73%|███████▎  | 499/681 [00:10<00:03, 46.46it/s, now=None]
# t:  74%|███████▍  | 504/681 [00:10<00:04, 41.65it/s, now=None]
# ==============================FINAL COUNT 26 13
# ==============================FINAL COUNT 31 13
# ==============================FINAL COUNT 29 12
# ==============================FINAL COUNT 35 13
# ==============================FINAL COUNT 16 17
# ==============================FINAL COUNT 29 14
# ==============================FINAL COUNT 16 9
# ==============================FINAL COUNT 27 6
# ==============================FINAL COUNT 13 4
# t:  75%|███████▍  | 509/681 [00:10<00:03, 43.02it/s, now=None]
# ==============================FINAL COUNT 37 7
# ==============================FINAL COUNT 11 8
# ==============================FINAL COUNT 24 9
# ==============================FINAL COUNT 37 13
# ==============================FINAL COUNT 24 14
# ==============================FINAL COUNT 16 13
# ==============================FINAL COUNT 19 14
# ==============================FINAL COUNT 11 14
# t:  75%|███████▌  | 514/681 [00:10<00:04, 41.18it/s, now=None]
# t:  76%|███████▋  | 520/681 [00:10<00:03, 45.43it/s, now=None]
# ==============================FINAL COUNT 33 10
# ==============================FINAL COUNT 26 8
# ==============================FINAL COUNT 22 7
# ==============================FINAL COUNT 11 6
# ==============================FINAL COUNT 20 7
# ==============================FINAL COUNT 35 5
# ==============================FINAL COUNT 26 7
# ==============================FINAL COUNT 26 9
# ==============================FINAL COUNT 26 6
# ==============================FINAL COUNT 34 12
# t:  77%|███████▋  | 525/681 [00:11<00:03, 45.10it/s, now=None]
# t:  78%|███████▊  | 530/681 [00:11<00:03, 43.61it/s, now=None]
# ==============================FINAL COUNT 31 16
# ==============================FINAL COUNT 18 15
# ==============================FINAL COUNT 27 17
# ==============================FINAL COUNT 13 11
# ==============================FINAL COUNT 29 6
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 19 5
# ==============================FINAL COUNT 21 6
# ==============================FINAL COUNT 20 5
# ==============================FINAL COUNT
# t:  79%|███████▊  | 536/681 [00:11<00:03, 45.90it/s, now=None]
#  23 7
# ==============================FINAL COUNT 27 8
# ==============================FINAL COUNT 26 11
# ==============================FINAL COUNT 9 9
# ==============================FINAL COUNT 40 18
# ==============================FINAL COUNT 36 16
# ==============================FINAL COUNT 28 9
# t:  79%|███████▉  | 541/681 [00:11<00:03, 40.91it/s, now=None]
# t:  80%|████████  | 546/681 [00:11<00:03, 38.83it/s, now=None]
# ==============================FINAL COUNT 25 10
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 28 5
# ==============================FINAL COUNT 28 6
# ==============================FINAL COUNT 24 2
# ==============================FINAL COUNT 14 5
# ==============================FINAL COUNT 24 7
# ==============================FINAL COUNT 25 14
# t:  81%|████████  | 552/681 [00:11<00:03, 41.45it/s, now=None]
# ==============================FINAL COUNT 22 9
# ==============================FINAL COUNT 31 16
# ==============================FINAL COUNT 25 15
# ==============================FINAL COUNT 21 13
# ==============================FINAL COUNT 22 13
# ==============================FINAL COUNT 25 5
# ==============================FINAL COUNT 29 3
# ==============================FINAL COUNT 21 5
# ==============================FINAL COUNT 31 6
# t:  82%|████████▏ | 557/681 [00:11<00:02, 41.82it/s, now=None]
# t:  83%|████████▎ | 562/681 [00:12<00:03, 35.77it/s, now=None]
# ==============================FINAL COUNT 12 8
# ==============================FINAL COUNT 24 7
# ==============================FINAL COUNT 20 11
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 32 11
# ==============================FINAL COUNT
# t:  83%|████████▎ | 567/681 [00:12<00:03, 34.61it/s, now=None]
#  17 18
# ==============================FINAL COUNT 29 15
# ==============================FINAL COUNT 16 8
# ==============================FINAL COUNT 26 6
# ==============================FINAL COUNT 26 2
# ==============================FINAL COUNT 37 4
# ==============================FINAL COUNT 14 9
# t:  84%|████████▍ | 571/681 [00:12<00:03, 35.66it/s, now=None]
# t:  84%|████████▍ | 575/681 [00:12<00:03, 33.85it/s, now=None]
# ==============================FINAL COUNT 23 9
# ==============================FINAL COUNT 25 7
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 15 13
# ==============================FINAL COUNT 16 10
# ==============================FINAL COUNT 19 15
# ==============================FINAL COUNT 22 18
# ==============================FINAL COUNT 25 10
# ==============================FINAL COUNT 18 7
# ==============================FINAL COUNT 24 3
# t:  85%|████████▌ | 580/681 [00:12<00:02, 37.04it/s, now=None]
# t:  86%|████████▌ | 584/681 [00:12<00:02, 37.60it/s, now=None]
# ==============================FINAL COUNT 21 8
# ==============================FINAL COUNT 26 3
# ==============================FINAL COUNT 26 5
# ==============================FINAL COUNT 16 3
# ==============================FINAL COUNT 16 7
# ==============================FINAL COUNT 17 12
# ==============================FINAL COUNT 10 9
# t:  86%|████████▋ | 588/681 [00:12<00:02, 37.55it/s, now=None]
# t:  87%|████████▋ | 593/681 [00:12<00:02, 39.95it/s, now=None]
# ==============================FINAL COUNT 17 15
# ==============================FINAL COUNT 18 19
# ==============================FINAL COUNT 24 10
# ==============================FINAL COUNT 23 13
# ==============================FINAL COUNT 17 4
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 18 4
# ==============================FINAL COUNT 20 3
# ==============================FINAL COUNT 20 6
# ==============================FINAL COUNT 20 8
# t:  88%|████████▊ | 598/681 [00:13<00:01, 41.80it/s, now=None]
# t:  89%|████████▊ | 603/681 [00:13<00:01, 42.32it/s, now=None]
# ==============================FINAL COUNT 18 2
# ==============================FINAL COUNT 18 10
# ==============================FINAL COUNT 23 11
# ==============================FINAL COUNT 19 12
# ==============================FINAL COUNT 23 17
# ==============================FINAL COUNT 29 10
# ==============================FINAL COUNT 25 9
# ==============================FINAL COUNT 27 5
# ==============================FINAL COUNT 10 6
# ==============================FINAL COUNT 20 7
# t:  89%|████████▉ | 609/681 [00:13<00:01, 46.18it/s, now=None]
# t:  90%|█████████ | 614/681 [00:13<00:01, 44.07it/s, now=None]
# ==============================FINAL COUNT 24 9
# ==============================FINAL COUNT 21 3
# ==============================FINAL COUNT 20 8
# ==============================FINAL COUNT 24 13
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 27 17
# ==============================FINAL COUNT 24 12
# ==============================FINAL COUNT 12 10
# ==============================FINAL COUNT 23 5
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 20 2
# t:  91%|█████████ | 620/681 [00:13<00:01, 47.11it/s, now=None]
# ==============================FINAL COUNT 22 5
# ==============================FINAL COUNT 20 3
# ==============================FINAL COUNT 18 4
# ==============================FINAL COUNT 18 6
# ==============================FINAL COUNT 14 8
# ==============================FINAL COUNT 22 11
# ==============================FINAL COUNT 20 12
# ==============================FINAL COUNT 22 11
# t:  92%|█████████▏| 625/681 [00:13<00:01, 44.39it/s, now=None]
# t:  93%|█████████▎| 630/681 [00:13<00:01, 41.88it/s, now=None]
# ==============================FINAL COUNT 21 11
# ==============================FINAL COUNT 16 11
# ==============================FINAL COUNT 22 7
# ==============================FINAL COUNT 25 1
# ==============================FINAL COUNT 18 4
# ==============================FINAL COUNT 21 5
# ==============================FINAL COUNT 16 4
# ==============================FINAL COUNT 16 3
# ==============================FINAL COUNT 14 8
# t:  93%|█████████▎| 635/681 [00:13<00:01, 42.66it/s, now=None]
# t:  94%|█████████▍| 640/681 [00:13<00:00, 44.37it/s, now=None]
# ==============================FINAL COUNT 13 7
# ==============================FINAL COUNT 24 11
# ==============================FINAL COUNT 25 15
# ==============================FINAL COUNT 14 8
# ==============================FINAL COUNT 27 4
# ==============================FINAL COUNT 16 9
# ==============================FINAL COUNT 20 3
# ==============================FINAL COUNT 30 4
# ==============================FINAL COUNT 19 3
# t:  95%|█████████▍| 645/681 [00:14<00:00, 43.76it/s, now=None]
# t:  95%|█████████▌| 650/681 [00:14<00:00, 42.69it/s, now=None]
# ==============================FINAL COUNT 23 5
# ==============================FINAL COUNT 14 9
# ==============================FINAL COUNT 29 6
# ==============================FINAL COUNT 9 8
# ==============================FINAL COUNT 13 9
# ==============================FINAL COUNT 20 11
# ==============================FINAL COUNT 19 7
# ==============================FINAL COUNT 21 10
# ==============================FINAL COUNT 9 11
# ==============================FINAL COUNT 17 5
# t:  96%|█████████▌| 655/681 [00:14<00:00, 42.60it/s, now=None]
# t:  97%|█████████▋| 660/681 [00:14<00:00, 44.46it/s, now=None]
# ==============================FINAL COUNT 17 9
# ==============================FINAL COUNT 19 4
# ==============================FINAL COUNT 24 6
# ==============================FINAL COUNT 13 6
# ==============================FINAL COUNT 17 8
# ==============================FINAL COUNT 31 4
# ==============================FINAL COUNT 27 9
# ==============================FINAL COUNT 22 12
# ==============================FINAL COUNT 32 11
# t:  98%|█████████▊| 665/681 [00:14<00:00, 44.76it/s, now=None]
# t:  98%|█████████▊| 670/681 [00:14<00:00, 43.80it/s, now=None]
# ==============================FINAL COUNT 15 17
# ==============================FINAL COUNT 28 9
# ==============================FINAL COUNT 21 12
# ==============================FINAL COUNT 22 2
# ==============================FINAL COUNT 31 3
# ==============================FINAL COUNT 25 5
# ==============================FINAL COUNT 23 6
# ==============================FINAL COUNT 25 7
# ==============================FINAL COUNT 23 7
# ==============================FINAL COUNT 29 4
# t:  99%|█████████▉| 677/681 [00:14<00:00, 45.27it/s, now=None]
# ==============================FINAL COUNT 16 9
# ==============================FINAL COUNT 17 22
# ==============================FINAL COUNT 16 14
# ==============================FINAL COUNT 15 10
# ==============================FINAL COUNT 20 9
# ==============================FINAL COUNT 32 6
# ==============================FINAL COUNT 19 4
# ==============================FINAL COUNT 17 7
# ==============================FINAL COUNT 25 4
# ==============================FINAL COUNT 33 3
# t:  93%|█████████▎| 632/681 [01:32<00:01, 47.38it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready test_videos_output/solidYellowLeft.mp4
# Wall time: 15.5 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidYellowLeft.mp4">
# </video>

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'test_videos_output/challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
